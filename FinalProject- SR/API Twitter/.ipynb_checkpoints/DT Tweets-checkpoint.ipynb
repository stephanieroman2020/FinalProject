# %%
#Importing dependencies
import tweepy           
import pandas as pd    
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Seperate folder with API tokens
from credentials import *

# %%
def twitter_setup():
    
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)

    api = tweepy.API(auth)
    return api

# %%
extractor = twitter_setup()

tweets = extractor.user_timeline(screen_name="realDonaldTrump", count=500)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

print("5 recent tweets:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 200.
#
# 5 recent tweets:
#
# https://t.co/VfrOSwXoqU
#
# https://t.co/ZawRDjsldB
#
# https://t.co/wwjRRx4W0P
#
# Great businessman &amp; philanthropist Bernie Marcus, Co-Founder of Home Depot, said that Congress was too distracted b… https://t.co/TSBYm9No2h
#
# HAPPY EASTER!
#
# A very good sign is that empty hospital beds are becoming more and more prevalent. We deployed 418 Doctors, Nurses… https://t.co/yjCvNerv9H
#
# RT @realDonaldTrump: Wishing all a safe and blessed Easter Sunday. I will be tuning into Pastor @robertjeffress at https://t.co/roBC6bOARn…
#
# HAPPY EASTER! https://t.co/UX5Bhm82H2
#
# https://t.co/b3fwPSkSCF
#
# RT @SteveScalise: Let's be clear about what's going on:
#
# Republicans are trying to replenish the Paycheck Protection Program before funds r…
#
# RT @MarioDB: What a great story.
#
# @AmericanAir has turned the Admirals Club at @iflymia into a mask-making factory! During a time of crisi…
#
# RT @HouseGOP: The #PaycheckProtectionProgram is a lifeline for small businesses on Main Street across America.
#
# Congress must urgently pas…
#
# RT @senatemajldr: Small business layoffs spiked 1,000% last month. 10% of the U.S. workforce is now jobless. This is no time for political…
#
# RT @GOPLeader: The Paycheck Protection Program has been so successful for America’s small businesses that it is projected to run out of mon…
#
# Cryin’Chuck doesn’t have a clue. Couldn’t care less about the American Worker! https://t.co/eoXxXdn460
#
# RT @GOPLeader: Speaker Pelosi has said she is aware of 'no data as to why we need' more funding for Americans’ paychecks. Anyone paying att…
#
# RT @FLOTUS: On the eve of #Easter, let us remember the ones who lost their lives to COVID19. Please try to connect w/ family, friends &amp; lov…
#
# RT @FLOTUS: It is a great honor to serve the people of this incredible country. 🇺🇸 #InaugurationDay2017 https://t.co/4SEj2VBxXO
#
# Mail in ballots substantially increases the risk of crime and VOTER FRAUD!
#
# Will be interviewed by @JudgeJeanine tonight at 9:00 P.M. Eastern on @FoxNews! https://t.co/F83yVaxXab
#
# So now the Fake News @nytimes is tracing the CoronaVirus origins back to Europe, NOT China. This is a first! I wond… https://t.co/4WO2qkEN51
#
# Governor @GavinNewsom of California has been very nice &amp;  highly supportive about the great job we have done, worki… https://t.co/X1BE6wUjSC
#
# I will be watching. HAVE A GREAT EASTER! https://t.co/wCa7u6qSnl
#
# RT @robertjeffress: During our 152-year history in downtown Dallas Presidents Woodrow Wilson, Gerald Ford, &amp; George H. W. Bush have worship…
#
# RT @robertjeffress: Thank you, President @realDonaldTrump! We are honored to have you join us and are grateful for your strong leadership o…
#
# The Wall Street Journal Editorial Board doesn’t have a clue on how to fight and win. Their views on Tariffs &amp; Trade… https://t.co/S8NNL1OBpd
#
# Watching @FoxNews on weekend afternoons is a total waste of time. We now have some great alternatives, like @OANN.
#
# “The President and the Federal Government are doing an excellent job. When they say the death toll isn’t going to b… https://t.co/4lgwo8AQLc
# RT @CNBCnow: BREAKING: Democrats block McConnell’s effort to get unanimous support for $250 billion in additional small business aid
# https…
#
# RT @AndrewHClark: Slow slow Sleepy Joe https://t.co/Fuoki6vGYO
#
# Tim Scott is Great! https://t.co/O1Aivbc2yG
#
# Thank you Frank. It’s ABC Fake News. They knew they were wrong when they went with this Hoax of a story! https://t.co/FHkRaW3BTi
#
# RT @JuddPDeere45: .@realDonaldTrump and @senatemajldr are fighting to help small businesses across this country. #COVID19 #AmericaWorksToge…
#
# RT @MZanona: House Minority Leader Kevin McCarthy said it's “disgusting” that Dems are pushing to include money for mail-in voting in the n…
#
# RT @Surabees: Just like @CNN did earlier today, here's @nytimes once again changing a headline to protect their close personal friends in t…
#
# RT @ErinMPerrine: 100% mail in voting is ripe for fraud. States should maintain the responsibility for their voting laws.
#
# Democrats want t…
#
# RT @FLOTUS: Today I joined @POTUS, @VP, &amp; @SecondLady on a call w Mental Health Professionals. Americans are enduring many hardships becaus…
#
# RT @BenGoldey: President @realDonaldTrump just announced: “Student loan payments have been waived for 6 months, and we'll discuss it after…
#
# RT @GOPconvention: “The Republican Convention is going to be such a benefit for the city. It’s going to show everyone around the world that…
#
# Thank you Erin! https://t.co/m8HRlK6VCY
#
# RT @Jim_Jordan: Chuck Schumer will never pass up an opportunity to play partisan games.
# https://t.co/SrMlN4MR7X
#
# RT @realDonaldTrump: The Wall Street Journal always “forgets” to mention that the ratings for the White House Press Briefings are “through…
#
# RT @realDonaldTrump: Great News: Prime Minister Boris Johnson has just been moved out of Intensive Care. Get well Boris!!!
#
# RT @realDonaldTrump: On National Former Prisoner of War Recognition Day, we honor the more than 500,000 American warriors captured while pr…

# %%
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
display(data.head(10))
# Out:
#                                               Tweets
# 0  Great businessman &amp; philanthropist Bernie ...
# 1                                      HAPPY EASTER!
# 2  A very good sign is that empty hospital beds a...
# 3  RT @realDonaldTrump: Wishing all a safe and bl...
# 4              HAPPY EASTER! https://t.co/UX5Bhm82H2
# 5                            https://t.co/b3fwPSkSCF
# 6  RT @SteveScalise: Let's be clear about what's ...
# 7  RT @MarioDB: What a great story. \n\n@American...
# 8  RT @HouseGOP: The #PaycheckProtectionProgram i...
# 9  RT @senatemajldr: Small business layoffs spike...

# %%
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1249370410422095872
# 2020-04-12 16:14:52
# Twitter for iPhone
# 11103
# 2882
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/TSBYm9No2h', 'expanded_url': 'https://twitter.com/i/web/status/1249370410422095872', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}

# %%
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# %%
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0  Great businessman &amp; philanthropist Bernie ...  144
# 1                                      HAPPY EASTER!   13
# 2  A very good sign is that empty hospital beds a...  139
# 3  RT @realDonaldTrump: Wishing all a safe and bl...  139
# 4              HAPPY EASTER! https://t.co/UX5Bhm82H2   37
# 5                            https://t.co/b3fwPSkSCF   23
# 6  RT @SteveScalise: Let's be clear about what's ...  140
# 7  RT @MarioDB: What a great story. \n\n@American...  140
# 8  RT @HouseGOP: The #PaycheckProtectionProgram i...  140
# 9  RT @senatemajldr: Small business layoffs spike...  139
#
#                     ID                Date              Source   Likes    RTs
# 0  1249370410422095872 2020-04-12 16:14:52  Twitter for iPhone   11103   2882
# 1  1249341983702876161 2020-04-12 14:21:55  Twitter for iPhone  202550  29177
# 2  1249341768157495296 2020-04-12 14:21:03  Twitter for iPhone   82182  16030
# 3  1249341655251062785 2020-04-12 14:20:36  Twitter for iPhone       0  12515
# 4  1249307795196952576 2020-04-12 12:06:04  Twitter for iPhone  194469  38875
# 5  1249144850357903360 2020-04-12 01:18:34  Twitter for iPhone   51679  13852
# 6  1249136141112152064 2020-04-12 00:43:58  Twitter for iPhone       0  32029
# 7  1249135849134067713 2020-04-12 00:42:48  Twitter for iPhone       0   4938
# 8  1249135682011922433 2020-04-12 00:42:09  Twitter for iPhone       0   6296
# 9  1249135484833595392 2020-04-12 00:41:22  Twitter for iPhone       0  11593

# %%
mean = np.mean(data['len'])

# %%
print("The lenght's average in tweets: {}".format(mean))
# Out:
# The lenght's average in tweets: 111.6

# %%
fav_max = np.max(data['Likes'])
rt_max  = np.max(data['RTs'])

fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

print("The tweet with more likes is: \n{}".format(data['Tweets'][fav]))
print("Number of likes: {}".format(fav_max))
print("{} characters.\n".format(data['len'][fav]))

print("The tweet with more retweets is: \n{}".format(data['Tweets'][rt]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(data['len'][rt]))
# Out:
# The tweet with more likes is:
# The W.H.O. really blew it. For some reason, funded largely by the United States, yet very China centric. We will be… https://t.co/3C2NWDafia
# Number of likes: 467049
# 140 characters.
#
# The tweet with more retweets is:
# The W.H.O. really blew it. For some reason, funded largely by the United States, yet very China centric. We will be… https://t.co/3C2NWDafia
# Number of retweets: 114300
# 140 characters.

# %%
tlen = pd.Series(data=data['len'].values, index=data['Date'])
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

# %%
tlen.plot(figsize=(16,4), color='r');

# %%
tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True);

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1
    
#1 means positive, 0 means neutral, -1 means negative

# %%
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4939cc46af3b> in <module>
# ----> 1 data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])
#
# NameError: name 'np' is not defined

# %%
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0  Great businessman &amp; philanthropist Bernie ...  144
# 1                                      HAPPY EASTER!   13
# 2  A very good sign is that empty hospital beds a...  139
# 3  RT @realDonaldTrump: Wishing all a safe and bl...  139
# 4              HAPPY EASTER! https://t.co/UX5Bhm82H2   37
# 5                            https://t.co/b3fwPSkSCF   23
# 6  RT @SteveScalise: Let's be clear about what's ...  140
# 7  RT @MarioDB: What a great story. \n\n@American...  140
# 8  RT @HouseGOP: The #PaycheckProtectionProgram i...  140
# 9  RT @senatemajldr: Small business layoffs spike...  139
#
#                     ID                Date              Source   Likes    RTs  \
# 0  1249370410422095872 2020-04-12 16:14:52  Twitter for iPhone   11103   2882
# 1  1249341983702876161 2020-04-12 14:21:55  Twitter for iPhone  202550  29177
# 2  1249341768157495296 2020-04-12 14:21:03  Twitter for iPhone   82182  16030
# 3  1249341655251062785 2020-04-12 14:20:36  Twitter for iPhone       0  12515
# 4  1249307795196952576 2020-04-12 12:06:04  Twitter for iPhone  194469  38875
# 5  1249144850357903360 2020-04-12 01:18:34  Twitter for iPhone   51679  13852
# 6  1249136141112152064 2020-04-12 00:43:58  Twitter for iPhone       0  32029
# 7  1249135849134067713 2020-04-12 00:42:48  Twitter for iPhone       0   4938
# 8  1249135682011922433 2020-04-12 00:42:09  Twitter for iPhone       0   6296
# 9  1249135484833595392 2020-04-12 00:41:22  Twitter for iPhone       0  11593
#
#    SA
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# 5   0
# 6   1
# 7   1
# 8  -1
# 9  -1

# %%
pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# %%
print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 45.5%
# Percentage of neutral tweets: 37.5%
# Percentage de negative tweets: 17.0%

# %%
data['Date'] = data['Date'].dt.strftime('%Y%m%d %H%M')
data.head()
# Out:
#                                               Tweets  len  \
# 0  Great businessman &amp; philanthropist Bernie ...  144
# 1                                      HAPPY EASTER!   13
# 2  A very good sign is that empty hospital beds a...  139
# 3  RT @realDonaldTrump: Wishing all a safe and bl...  139
# 4              HAPPY EASTER! https://t.co/UX5Bhm82H2   37
#
#                     ID           Date              Source   Likes    RTs  SA
# 0  1249370410422095872  20200412 1614  Twitter for iPhone   11103   2882   1
# 1  1249341983702876161  20200412 1421  Twitter for iPhone  202550  29177   1
# 2  1249341768157495296  20200412 1421  Twitter for iPhone   82182  16030   1
# 3  1249341655251062785  20200412 1420  Twitter for iPhone       0  12515   1
# 4  1249307795196952576  20200412 1206  Twitter for iPhone  194469  38875   1

# %%
data.to_csv('FinalTrumpTweet_test.csv', index = False, header=True)
